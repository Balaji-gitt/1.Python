# %%
lists=[22,33,44,55,66]

# %%
for temp in lists:
    print(temp)
# Out:
# 22
# 33
# 44
# 55
# 66

# %%
for age in lists:
    if (age<18):
        print("Children")
    elif (age<35):
        print("Adult")
    elif (age<50):
        print("citizen")
    else:
        print("senior citizen")
# Out:
# Adult
# Adult
# citizen
# senior citizen
# senior citizen
