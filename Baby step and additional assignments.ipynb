# %%
#Add the number
num1=10
num2=30
add=num1+num2
print (add)
# Out:
# 40

# %%
#Add the number
num1=int(input("Enter the 1st number:"))
num2=int(input("Enter the 2nd number:"))
add=num1+num2
print("The Answer is:", add)
# Out:
# Enter the 1st number:35
# Enter the 2nd number:55
# The Answer is: 90

# %%
#Body Mass Index
BMI=int(input("Enter the body mass index:"))
if BMI<18:
    print("under weight")
elif BMI>=24:
    print("Normal BMI")
else:
    print("Over weight")
# Out:
# Enter the body mass index:12
# under weight

# %%
BMI=int(input("Enter the body mass index:"))
if BMI<18:
    print("under weight")
elif BMI==33:
    print("Normal BMI")
else:
    print("Over weight")
# Out:
# Enter the body mass index:33
# Normal BMI

# %%
BMI=int(input("Enter the body mass index:"))
if BMI<18:
    print("under weight")
elif BMI==33:
    print("Normal BMI")
else:
    print("Over weight")
# Out:
# Enter the body mass index:35
# Over weight

# %%
#need correction here

BMI=int(input("Enter the body mass index:"))
if BMI<18:
    print("under weight")
elif BMI>=18 <24:
    print("Normal BMI")
elif BMI >=25 <33:
    print("Over weight")
else:
    print("Obese")
# Out:
# Enter the body mass index:35
# Normal BMI
