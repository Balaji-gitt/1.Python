# %%
A=10
B=20
Add=A+B
print(A+B)
print(Add)
print(A)
# Out:
# 30
# 30
# 10

# %%
flower1=20
flower2=30
add=flower1+flower2
Substract=flower1-flower2
multiply=flower1*flower2
divide=flower1/flower2
print(add)
print(Substract)
print(multiply)
print(divide)
# Out:
# 50
# -10
# 600
# 0.6666666666666666

# %%
First_name="Balaji"
Second_name="Ragavendran"
Add=(First_name+Second_name)
print(Add)
# Out:
# BalajiRagavendran

# %%
print("The Addition of 2 Numbers")
Num1=20
Num2=30
print("1st number is:", Num1)
print("2nd number is:", Num2)
print("The Answer is:", add)
add=Num1+Num2
# Out:
# The Addition of 2 Numbers
# 1st number is: 20
# 2nd number is: 30
# The Answer is: 50

# %%
num1=int(input("Enter the number1: "))
num2=int(input("Enter the number2: "))
add=num1+num2
print("The answer is", add)
# Out:
# Enter the number1: 10
# Enter the number2: 19
# The answer is 29
