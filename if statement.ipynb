# %%
age = 18

if age == 18:
    print("adult")
# Out:
# adult

# %%
age=int(input("Enter the age:"))
# Out:
# Enter the age:22

# %%
age=int(input("Enter the age:"))
if (age>=18):
    print("Adult")
# Out:
# Enter the age:22
# Adult

# %%
age=int(input("Enter the age:"))
if (age==18):
    print("Adult")
# Out:
# Enter the age:18
# Adult

# %%
age=int(input("Enter the age:"))
if (age>=18):
    print("Adult")
if (age<=18):
    print("Children")
# Out:
# Enter the age:14
# Children

# %%
Acc_Number=input("Enter the Acc_number.startswith:")
if (Acc_Number.startswith("1")):
    print("A Bank")
elif (Acc_Number.startswith("2")):
    print("B Bank")
else:
    print("Unknown Bank")
# Out:
# Enter the Acc_number.startswith:3456
# Unknown Bank

# %%
Acc_Number=input("Enter the Acc_number.startswith:")
if (Acc_Number.startswith("1")):
    print("A Bank")
elif (Acc_Number.startswith("2")):
    print("B Bank")
else:
    print("Unknown Bank")
# Out:
# Enter the Acc_number.startswith:123466
# A Bank

# %%
Acc_Number=input("Enter the Acc_number.startswith:")
if (Acc_Number.startswith("1")):
    print("A Bank")
elif (Acc_Number.startswith("2")):
    print("B Bank")
else:
    print("Unknown Bank")
# Out:
# Enter the Acc_number.startswith:23443
# B Bank

# %%
age=int(input("Enter the age:"))
if (age>=18):
    print("Adult")
elif (age<=18):
    print("Children")
# Out:
# Enter the age:16
# Children

# %%
age=int(input("Enter the age:"))
if (age>=18):
    print("Adult")
elif (age<=18):
    print("Children")
# Out:
# Enter the age:19
# Adult

# %%
age=int(input("Enter the age:"))
if (age<18):
    print("Children")
elif (age<59):
    print("citizen")
else:
    print("Senior citizen")
# Out:
# Enter the age:16
# Children

# %%
age=int(input("Enter the age:"))
if (age<18):
    print("Children")
elif (age<59):
    print("citizen")
else:
    print("Senior citizen")
# Out:
# Enter the age:19
# citizen

# %%
age=int(input("Enter the age:"))
if (age<18):
    print("Children")
elif (age<59):
    print("citizen")
else:
    print("Senior citizen")
# Out:
# Enter the age:60
# Senior citizen
